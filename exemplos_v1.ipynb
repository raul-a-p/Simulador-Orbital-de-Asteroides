# %% [markdown]
# # Simulador Orbital de Asteroides — Exemplos de Uso

# %%
# EXECUÇÃO DO SIMULADOR ORBITAL DE ASTEROIDES V1
from simulador_orbital_asteroides_v1 import *
# Out:
# ✓ Bibliotecas e constantes carregadas com sucesso!
# ✓ Classe CorpoCeleste definida!
# ✓ Classe ResultadoSimulacao definida!
# ✓ Funções de configuração criadas!
# ✓ Funções de visualização criadas!
# ✓ Funções de Monte Carlo criadas!
# ✓ Funções de I/O criadas!
# ✓ Interface de menu criada!
# ✓ Testes de validação criados!
# ✓ Exemplos de uso criados!
#
# ======================================================================
#                📊 SIMULADOR DE TRAJETÓRIAS DE ASTEROIDES
# ======================================================================
#
# ✓ Todas as funções carregadas com sucesso!
#
# Opções de execução:
#   1. executar_simulacao_interativa()  - Menu interativo completo
#   2. exemplo_basico()                 - Órbita da Terra (validação)
#   3. exemplo_apophis()                - Asteroide Apophis
#   4. exemplo_impacto()                - Cenário de impacto
#   5. exemplo_monte_carlo()            - Análise estatística
#   6. exemplo_personalizado()          - Configuração customizada
#   7. executar_todos_testes()          - Validação completa
#
# Execute qualquer uma dessas funções!
# Exemplo: executar_simulacao_interativa()
# Opcional: use o "%matplotlib widget" para tornar os gráficos interativos
# ======================================================================
#
# ======================================================================
#                      ✓ CÓDIGO COMPLETO CARREGADO!
# ======================================================================
#
# Para começar, execute:
#   • executar_simulacao_interativa()  (menu interativo)
#   • exemplo_apophis()                (exemplo rápido)
#   • executar_todos_testes()          (validação)
#   • mostrar_ajuda()                  (documentação)
# ======================================================================

# %% [markdown]
# ## Exemplo 1 — Menu interativo (opção completa)

# %%
executar_simulacao_interativa()
# Out:
# ======================================================================
#                 SIMULADOR DE TRAJETÓRIAS DE ASTEROIDES
# ======================================================================
#
# Escolha uma opção:
#
# 1. CASOS PRÉ-CONFIGURADOS
#    a) Órbita da Terra (validação)
#    b) Asteroide Apophis (2029)
#    c) Cenário de impacto hipotético
#
# 2. CONFIGURAÇÃO PERSONALIZADA
#    d) Inserir parâmetros manualmente
#    e) Gerar condições aleatórias
#
# 3. SIMULAÇÃO MONTE CARLO
#    f) Executar análise estatística
#
# 4. CARREGAR CONFIGURAÇÃO
#    g) Carregar de arquivo JSON
#
# 0. Sair
# ======================================================================
# Digite sua opção:  0
# Encerrando simulador. Até logo!

# %% [markdown]
# ## Exemplo 2 — Órbita da Terra ao redor do Sol

# %%
exemplo_basico()
# Out:
# ======================================================================
#             EXEMPLO 1: Simulação Básica (Órbita da Terra)
# ======================================================================
# Progresso: 0.0% (0/17532 passos)
# Progresso: 5.0% (876/17532 passos)
# Progresso: 10.0% (1752/17532 passos)
# Progresso: 15.0% (2628/17532 passos)
# Progresso: 20.0% (3504/17532 passos)
# Progresso: 25.0% (4380/17532 passos)
# Progresso: 30.0% (5256/17532 passos)
# Progresso: 35.0% (6132/17532 passos)
# Progresso: 40.0% (7008/17532 passos)
# Progresso: 45.0% (7884/17532 passos)
# Progresso: 50.0% (8760/17532 passos)
# Progresso: 55.0% (9636/17532 passos)
# Progresso: 60.0% (10512/17532 passos)
# Progresso: 65.0% (11388/17532 passos)
# Progresso: 70.0% (12264/17532 passos)
# Progresso: 74.9% (13140/17532 passos)
# Progresso: 79.9% (14016/17532 passos)
# Progresso: 84.9% (14892/17532 passos)
# Progresso: 89.9% (15768/17532 passos)
# Progresso: 94.9% (16644/17532 passos)
# Progresso: 99.9% (17520/17532 passos)
#
# ✓ Simulação concluída!
#
# ======================================================================
#                     RELATÓRIO DA SIMULAÇÃO ORBITAL
# ======================================================================
#
# INFORMAÇÕES TEMPORAIS:
#   Tempo total simulado: 2.00 anos
#   Número de passos: 17,532
#
# APROXIMAÇÃO MÍNIMA:
#   Distância mínima: inf km
#   Distância em raios terrestres: inf R⊕
#   Tempo da aproximação: 0.0000 anos
#   Velocidade relativa: 0.00 km/s
#
# ✓ Nenhuma colisão detectada
# VALIDAÇÃO FÍSICA:
#   Energia inicial: -2.649712e+33 J
#   Energia final: -2.649712e+33 J
#   Erro relativo de energia: 8.70e-15
#   ✓ Energia conservada dentro da tolerância
# OBSERVAÇÃO:
# 🔵 Posição inicial: círculo
# ⬛ Posição final: quadrado
#
# ======================================================================

# %%
sistema = criar_sistema_terra_sol()
resultado = sistema.simular(1 * ANOS_EM_SEGUNDOS, progresso=False)
print(resultado.gerar_relatorio())
plotar_trajetorias(sistema, "Órbita da Terra")
# Out:
# ======================================================================
#                     RELATÓRIO DA SIMULAÇÃO ORBITAL
# ======================================================================
#
# INFORMAÇÕES TEMPORAIS:
#   Tempo total simulado: 1.00 anos
#   Número de passos: 8,766
#
# APROXIMAÇÃO MÍNIMA:
#   Distância mínima: inf km
#   Distância em raios terrestres: inf R⊕
#   Tempo da aproximação: 0.0000 anos
#   Velocidade relativa: 0.00 km/s
#
# ✓ Nenhuma colisão detectada
# VALIDAÇÃO FÍSICA:
#   Energia inicial: -2.649712e+33 J
#   Energia final: -2.649712e+33 J
#   Erro relativo de energia: 1.33e-14
#   ✓ Energia conservada dentro da tolerância
# OBSERVAÇÃO:
# 🔵 Posição inicial: círculo
# ⬛ Posição final: quadrado
#
# ======================================================================

# %% [markdown]
# ## Exemplo 3 — Asteroide Apophis (aproximação 2029)

# %%
exemplo_apophis()
# Out:
# ======================================================================
#                  EXEMPLO 2: Asteroide Apophis (2029)
# ======================================================================
# Progresso: 0.0% (0/26298 passos)
# Progresso: 5.0% (1314/26298 passos)
# Progresso: 10.0% (2628/26298 passos)
# Progresso: 15.0% (3942/26298 passos)
# Progresso: 20.0% (5256/26298 passos)
# Progresso: 25.0% (6570/26298 passos)
# Progresso: 30.0% (7884/26298 passos)
# Progresso: 35.0% (9198/26298 passos)
# Progresso: 40.0% (10512/26298 passos)
# Progresso: 45.0% (11826/26298 passos)
# Progresso: 50.0% (13140/26298 passos)
# Progresso: 55.0% (14454/26298 passos)
# Progresso: 60.0% (15768/26298 passos)
# Progresso: 65.0% (17082/26298 passos)
# Progresso: 70.0% (18396/26298 passos)
# Progresso: 74.9% (19710/26298 passos)
# Progresso: 79.9% (21024/26298 passos)
# Progresso: 84.9% (22338/26298 passos)
# Progresso: 89.9% (23652/26298 passos)
# Progresso: 94.9% (24966/26298 passos)
# Progresso: 99.9% (26280/26298 passos)
#
# ✓ Simulação concluída!
#
# ======================================================================
#                     RELATÓRIO DA SIMULAÇÃO ORBITAL
# ======================================================================
#
# INFORMAÇÕES TEMPORAIS:
#   Tempo total simulado: 3.00 anos
#   Número de passos: 26,298
#
# APROXIMAÇÃO MÍNIMA:
#   Distância mínima: 16298785.32 km
#   Distância em raios terrestres: 2558.28 R⊕
#   Tempo da aproximação: 2.5264 anos
#   Velocidade relativa: 0.37 km/s
#
# ✓ Nenhuma colisão detectada
# VALIDAÇÃO FÍSICA:
#   Energia inicial: -2.649712e+33 J
#   Energia final: -2.649712e+33 J
#   Erro relativo de energia: 5.00e-15
#   ✓ Energia conservada dentro da tolerância
# OBSERVAÇÃO:
# 🔵 Posição inicial: círculo
# ⬛ Posição final: quadrado
#
# ======================================================================
# ✓ Resultado salvo em: apophis_resultado.txt
# ✓ Trajetórias exportadas para: apophis_trajetorias.json

# %%
sistema = criar_sistema_apophis()
resultado = sistema.simular(4 * ANOS_EM_SEGUNDOS, progresso=False)
print(resultado.gerar_relatorio())
plotar_trajetorias(sistema, "Apophis 2029")
# Out:
# ======================================================================
#                     RELATÓRIO DA SIMULAÇÃO ORBITAL
# ======================================================================
#
# INFORMAÇÕES TEMPORAIS:
#   Tempo total simulado: 4.00 anos
#   Número de passos: 35,064
#
# APROXIMAÇÃO MÍNIMA:
#   Distância mínima: 16298785.32 km
#   Distância em raios terrestres: 2558.28 R⊕
#   Tempo da aproximação: 2.5264 anos
#   Velocidade relativa: 0.37 km/s
#
# ✓ Nenhuma colisão detectada
# VALIDAÇÃO FÍSICA:
#   Energia inicial: -2.649712e+33 J
#   Energia final: -2.649712e+33 J
#   Erro relativo de energia: 1.63e-14
#   ✓ Energia conservada dentro da tolerância
# OBSERVAÇÃO:
# 🔵 Posição inicial: círculo
# ⬛ Posição final: quadrado
#
# ======================================================================

# %% [markdown]
# ## Exemplo 4 — Impacto garantido com a Terra

# %%
exemplo_impacto()
# Out:
# ======================================================================
#                EXEMPLO 3: Cenário de Impacto Hipotético
# ======================================================================
#
# 🎯 CENÁRIO DE IMPACTO
#    Velocidade Terra: 29.79 km/s
#    Velocidade Asteroide: 28.91 km/s
#    Velocidade relativa de impacto: ~58.70 km/s
#    Massa: 5.00e+08 kg
#    dt: 900s (15 min)
# Progresso: 0.0% (0/17532 passos)
# Progresso: 5.0% (876/17532 passos)
# Progresso: 10.0% (1752/17532 passos)
# Progresso: 15.0% (2628/17532 passos)
# Progresso: 20.0% (3504/17532 passos)
# Progresso: 25.0% (4380/17532 passos)
# Progresso: 30.0% (5256/17532 passos)
#
# 💥 COLISÃO COM A TERRA DETECTADA no passo 5948!
#    Tempo: 61.97 dias (0.1697 anos)
#
# ✓ Simulação concluída!
#
# ======================================================================
#                     RELATÓRIO DA SIMULAÇÃO ORBITAL
# ======================================================================
#
# INFORMAÇÕES TEMPORAIS:
#   Tempo total simulado: 0.17 anos
#   Número de passos: 17,532
#
# APROXIMAÇÃO MÍNIMA:
#   Distância mínima: 3622.96 km
#   Distância em raios terrestres: 0.57 R⊕
#   Tempo da aproximação: 0.1697 anos
#   Velocidade relativa: 58.62 km/s
#
# ⚠️  COLISÃO COM A TERRA DETECTADA!
#   Tempo de impacto: 0.1697 anos
#   Tempo de impacto: 62.0 dias
#   Velocidade de impacto: 58.62 km/s
#   Ângulo de impacto: 78.22°
#   Energia de impacto: 8.59e+17 J
#   Equivalente em TNT: 2.05e+02 megatons
#   Raio estimado da cratera: 69.82 km
# VALIDAÇÃO FÍSICA:
#   Energia inicial: -2.649712e+33 J
#   Energia final: -2.649712e+33 J
#   Erro relativo de energia: -4.57e-15
#   ✓ Energia conservada dentro da tolerância
# OBSERVAÇÃO:
# 🔵 Posição inicial: círculo
# ⬛ Posição final: quadrado
#
# ======================================================================

# %% [markdown]
# ## Exemplo 5 — Sistema aleatório

# %%
sistema = criar_sistema_aleatorio(seed=42)
resultado = sistema.simular(1 * ANOS_EM_SEGUNDOS, progresso=False)
print(resultado.gerar_relatorio())
plotar_trajetorias(sistema, "Órbita Aleatória")
# Out:
# ======================================================================
#                     RELATÓRIO DA SIMULAÇÃO ORBITAL
# ======================================================================
#
# INFORMAÇÕES TEMPORAIS:
#   Tempo total simulado: 1.00 anos
#   Número de passos: 8,766
#
# APROXIMAÇÃO MÍNIMA:
#   Distância mínima: 211648385.47 km
#   Distância em raios terrestres: 33220.59 R⊕
#   Tempo da aproximação: 0.1128 anos
#   Velocidade relativa: 45.37 km/s
#
# ✓ Nenhuma colisão detectada
# VALIDAÇÃO FÍSICA:
#   Energia inicial: -2.649712e+33 J
#   Energia final: -2.649712e+33 J
#   Erro relativo de energia: 1.33e-14
#   ✓ Energia conservada dentro da tolerância
# OBSERVAÇÃO:
# 🔵 Posição inicial: círculo
# ⬛ Posição final: quadrado
#
# ======================================================================

# %% [markdown]
# ## Exemplo 6 — Análise estatística

# %%
exemplo_monte_carlo()
# Out:
# ======================================================================
#                    EXEMPLO 4: Simulação Monte Carlo
# ======================================================================
# Iniciando simulação Monte Carlo com 15 cenários...
# ======================================================================
# Progresso: 7% (1/15 simulações)
# Progresso: 13% (2/15 simulações)
# Progresso: 20% (3/15 simulações)
# Progresso: 27% (4/15 simulações)
# Progresso: 33% (5/15 simulações)
# Progresso: 40% (6/15 simulações)
# Progresso: 47% (7/15 simulações)
# Progresso: 53% (8/15 simulações)
# Progresso: 60% (9/15 simulações)
# Progresso: 67% (10/15 simulações)
# Progresso: 73% (11/15 simulações)
# Progresso: 80% (12/15 simulações)
# Progresso: 87% (13/15 simulações)
# Progresso: 93% (14/15 simulações)
# Progresso: 100% (15/15 simulações)
#
# ======================================================================
#                  RESULTADOS DA SIMULAÇÃO MONTE CARLO
# ======================================================================
# Total de simulações: 15
# Colisões detectadas: 0
# Probabilidade de impacto: 0.00%
#
# Distância mínima:
#   Média: 45082.14 × 10³ km
#   Desvio padrão: 668.09 × 10³ km
#   Mínima: 43521.62 × 10³ km
#   Máxima: 46012.41 × 10³ km
#   Em raios terrestres: 7076.15 ± 104.86 R⊕
# ======================================================================

# %% [markdown]
# ## Exemplo 7 — Cenário personalizado

# %%
exemplo_personalizado(massa=1e10, posicao=[1*UA, 2*UA, 1*UA], velocidade=[0, 1000, -10])
# Out:
# ======================================================================
#                 EXEMPLO 5: Configuração Personalizada
# ======================================================================
# Progresso: 0.0% (0/17532 passos)
# Progresso: 5.0% (876/17532 passos)
# Progresso: 10.0% (1752/17532 passos)
# Progresso: 15.0% (2628/17532 passos)
# Progresso: 20.0% (3504/17532 passos)
# Progresso: 25.0% (4380/17532 passos)
# Progresso: 30.0% (5256/17532 passos)
# Progresso: 35.0% (6132/17532 passos)
#
# 🔥 ASTEROIDE CAIU NO SOL no passo 6180!
#    Tempo: 257.54 dias (0.7051 anos)
#
# ✓ Simulação concluída!
#
# ======================================================================
#                     RELATÓRIO DA SIMULAÇÃO ORBITAL
# ======================================================================
#
# INFORMAÇÕES TEMPORAIS:
#   Tempo total simulado: 0.71 anos
#   Número de passos: 17,532
#
# APROXIMAÇÃO MÍNIMA:
#   Distância mínima: 475952.45 km
#   Distância em raios terrestres: 74.71 R⊕
#   Tempo da aproximação: 0.7050 anos
#   Velocidade relativa: 364.50 km/s
#
# 🔥 ASTEROIDE CAIU NO SOL!
#   Tempo da queda: 0.7051 anos
#   Tempo da queda: 257.5 dias
#   Velocidade no impacto: 869.85 km/s
#   Energia liberada: 3.78e+21 J
# VALIDAÇÃO FÍSICA:
#   Energia inicial: -2.649712e+33 J
#   Energia final: -2.649712e+33 J
#   Erro relativo de energia: 3.90e-13
#   ✓ Energia conservada dentro da tolerância
# OBSERVAÇÃO:
# 🔵 Posição inicial: círculo
# ⬛ Posição final: quadrado
#
# ======================================================================

# %% [markdown]
# ## Exemplo 8 — Verificar leis físicas

# %%
executar_todos_testes()
# Out:
# ======================================================================
#                     EXECUTANDO TESTES DE VALIDAÇÃO
# ======================================================================
#
# TESTE 1: Conservação de Energia (Órbita Terra-Sol)
# ======================================================================
# Energia inicial: -2.649712e+33 J
# Energia final:   -2.649712e+33 J
# Erro relativo:   8.702239e-15
# Tolerância:      1.000000e-06
# ✓ TESTE PASSOU: Energia conservada!
#
# TESTE 2: Terceira Lei de Kepler
# ======================================================================
# Período simulado: 1.000000 anos
# Período teórico:  0.999892 anos
# Erro relativo:    1.081394e-04
# ✓ TESTE PASSOU: Período orbital correto!
#
# TESTE 3: Estabilidade Orbital
# ======================================================================
# Raio médio:       0.999991 UA
# Raio esperado:    1.000000 UA
# Variação relativa: 7.699797e-05
# ✓ TESTE PASSOU: Órbita estável!
#
# ======================================================================
#                           RESUMO DOS TESTES
# ======================================================================
# Total de testes: 3
# Testes passados: 3
# Testes falhados: 0
#
# ✓ TODOS OS TESTES PASSARAM!
# ======================================================================
# True

# %% [markdown]
# ## Exemplo 9 — Ajuda e documentação

# %%
mostrar_ajuda()
# Out:
#     ╔═══════════════════════════════════════════════════════════════════╗
#     ║       SIMULADOR ORBITAL DE ASTEROIDES - GUIA DE USO               ║
#     ╚═══════════════════════════════════════════════════════════════════╝
#
#     📚 CLASSES PRINCIPAIS:
#
#     1. CorpoCeleste
#        - Representa um corpo celeste (Sol, Terra, Asteroide)
#        - Atributos: nome, massa, posicao, velocidade, cor
#        - Métodos: salvar_estado(), energia_cinetica(), momento_angular()
#
#     2. SistemaGravitacional
#        - Gerencia múltiplos corpos e evolução temporal
#        - Métodos principais:
#          * adicionar_corpo(corpo)
#          * simular(tempo_total, progresso=True)
#          * energia_total()
#          * momento_angular_total()
#
#     3. ResultadoSimulacao
#        - Armazena resultados da simulação
#        - Método: gerar_relatorio()
#
#     ⚙️  FUNÇÕES DE CONFIGURAÇÃO:
#
#     - criar_sistema_terra_sol()      → Sistema Terra-Sol (validação)
#     - criar_sistema_apophis()        → Asteroide Apophis (2029)
#     - criar_sistema_impacto()        → Cenário de impacto hipotético
#     - criar_sistema_personalizado()  → Sistema com parâmetros customizados
#     - criar_sistema_aleatorio()      → Condições iniciais aleatórias
#
#     📊 FUNÇÕES DE VISUALIZAÇÃO:
#
#     - plotar_trajetorias(sistema)           → Órbitas em 2D
#     - plotar_distancia_temporal(sistema)    → Distância vs tempo
#     - plotar_conservacao_energia(sistema)   → Validação física
#     - criar_animacao(sistema, arquivo)      → Animação GIF
#     - plotar_resultados_monte_carlo(stats)  → Análise estatística
#
#     🎲 SIMULAÇÃO MONTE CARLO:
#
#     - simulacao_monte_carlo(n_simulacoes, variacao_posicao, variacao_velocidade)
#       → Executa múltiplas simulações com variações aleatórias
#       → Retorna estatísticas de risco de impacto
#
#     💾 FUNÇÕES DE I/O:
#
#     - salvar_configuracao(sistema, arquivo)   → Salva em JSON
#     - carregar_configuracao(arquivo)          → Carrega de JSON
#     - salvar_resultado(resultado, arquivo)    → Salva relatório
#     - exportar_trajetorias(sistema, arquivo)  → Exporta dados
#
#     🧪 TESTES DE VALIDAÇÃO:
#
#     - teste_conservacao_energia()    → Valida conservação de energia
#     - teste_terceira_lei_kepler()    → Valida período orbital
#     - teste_orbita_estavel()         → Valida estabilidade
#     - executar_todos_testes()        → Executa todos os testes
#
#     📖 EXEMPLOS DE USO:
#
#     Exemplo 1 - Simulação Básica:
#     ```python
#     sistema = criar_sistema_terra_sol()
#     resultado = sistema.simular(2 * ANOS_EM_SEGUNDOS)
#     print(resultado.gerar_relatorio())
#     plotar_trajetorias(sistema)
#     ```
#
#     Exemplo 2 - Apophis:
#     ```python
#     sistema = criar_sistema_apophis()
#     resultado = sistema.simular(3 * ANOS_EM_SEGUNDOS)
#     plotar_distancia_temporal(sistema)
#     ```
#
#     Exemplo 3 - Monte Carlo:
#     ```python
#     stats = simulacao_monte_carlo(n_simulacoes=100)
#     plotar_resultados_monte_carlo(stats)
#     ```
#
#     ⚡ CONSTANTES DISPONÍVEIS:
#
#     - G             → Constante gravitacional (6.674e-11)
#     - UA            → Unidade Astronômica (1.496e11 m)
#     - M_SOL         → Massa do Sol (1.989e30 kg)
#     - M_TERRA       → Massa da Terra (5.972e24 kg)
#     - R_TERRA       → Raio da Terra (6.371e6 m)
#     - ANOS_EM_SEGUNDOS → Segundos em um ano (31557600)
#
#     ════════════════════════════════════════════════════════════════════
